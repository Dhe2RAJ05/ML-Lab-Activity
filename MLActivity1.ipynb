# %%
#Importing necessary modules
import pandas as pd                  
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"chicago_taxi_trips.csv") #Accessing the .csv file
df.head()                                 #Raw Data
# Out:
#                                     Trip ID  \
# 0  0287f53fedcde6b0af9aab9e32cbd2cadb337eaa
# 1  1f0034299b914fd7b45002568576a353c83acb2f
# 2  01a0b77b722a0b91f45cb4fc90b3e64f76fd0681
# 3  14aff2071ac81c6450a8f8b0e1534497da900197
# 4  16d3a633e2f380cee4a7fa4677db163b6e91255d
#
#                                              Taxi ID    Trip Start Timestamp  \
# 0  e54db25f18193a08f1f5754515e8c338480e04fb938ed3...  03/01/2024 12:00:00 AM
# 1  4a263f78f56815be4acd38658af8fc1824ce4e15f7ec81...  03/01/2024 12:00:00 AM
# 2  4f1e94982e6851725add382f7981d64006ae7c38f3664f...  03/01/2024 12:00:00 AM
# 3  de8e8659ceb9eb0da842a46b60c0a5207098ac69fc23ab...  03/01/2024 12:00:00 AM
# 4  d79d3e19a1d5f6cb0cd4449d5579412262a2f1b182799d...  03/01/2024 12:00:00 AM
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  03/01/2024 12:00:00 AM          15.0        0.09                  NaN
# 1  03/01/2024 12:15:00 AM         900.0        3.00                  NaN
# ...

# %%
df = df[['Trip Miles', 'Pickup Community Area', 'Dropoff Community Area', 'Trip Total']]
df.head()
# Out:
#    Trip Miles  Pickup Community Area  Dropoff Community Area  Trip Total
# 0        0.09                    8.0                     8.0       38.75
# 1        3.00                   24.0                     8.0       12.00
# 2        5.84                   56.0                     NaN       26.70
# 3       13.36                   76.0                     3.0       47.10
# 4        6.13                    8.0                     3.0       22.82

# %%
df.shape
# Out:
# (865247, 4)

# %%
df.isnull().sum()
# Out:
# Trip Miles                    6
# Pickup Community Area     23195
# Dropoff Community Area    83853
# Trip Total                 2045
# dtype: int64

# %%
df=df.dropna()

# %%
X = df[['Trip Miles', 'Pickup Community Area', 'Dropoff Community Area']] 
y = df['Trip Total']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,              # input and output data
    test_size=0.2,     # 20% of data for testing 
    random_state=45    # assigning extent of randomness
)
print("Size of training data: ",len(X_train), "\nSize of test split: ",len(X_test))
# Out:
# Size of training data:  619088
# Size of test split:  154773

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict([[5,27,8]])
# Out:
# C:\Users\Deeraj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([21.09103973])

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred[:5])        
print(y_test[:5].values)
# Out:
# [17.10069065  7.74472303 47.16414024 11.97133559 25.57762005]
# [14.75 18.75 39.   11.24 18.75]

# %%
plt.scatter(y_test, y_pred, alpha=0.5, color='blue', label='Predicted vs Actual')

# Perfect Prediction Line
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--', label='Perfect Prediction')

# Title and Labels
plt.xlabel("Actual Fare")
plt.ylabel("Predicted Fare")
plt.title("Actual vs Predicted Taxi Fare")
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted Taxi Fare')

# %%
import pandas as pd

# %%
ds=pd.read_csv(r"weight.csv")
ds.head()
# Out:
#    Weight  Height  Age Gender
# 0      79    1.80   35   Male
# 1      69    1.68   39   Male
# 2      73    1.82   25   Male
# 3      95    1.70   60   Male
# 4      82    1.87   27   Male

# %%
ds.shape
# Out:
# (10, 4)

# %%
X=ds[["Height","Age"]]
y=ds["Weight"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,              # input and output data
    test_size=0.2,     # 20% for testing
    random_state=42    # extent of randomness
)

# %%
print("Size of training data: ",len(X_train), "\nSize of test split: ",len(X_test))
# Out:
# Size of training data:  8
# Size of test split:  2

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict([[1.8,23]])
# Out:
# C:\Users\Deeraj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([74.09682707])

# %%
y_pred = model.predict(X)

# %%
import matplotlib.pyplot as plt
plt.scatter(ds['Height'],ds['Weight'], alpha=0.5, color='blue', label='Predicted vs Actual',marker="+")

# Perfect prediction line
plt.plot(ds['Height'],y_pred, color='red', linestyle='--')

# Title and Labels
plt.xlabel("Height")
plt.ylabel("Weight")
plt.title("Height vs Weight")
# Out:
# Text(0.5, 1.0, 'Height vs Weight')
